# %%
! pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (0.16.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (3.12.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2023.4.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2.28.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2022.12.7)

# %% [markdown]
# # All imports necessary

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from datetime import datetime

# %%
from sqlalchemy import create_engine

# %%
import json

# %%
from huggingface_hub import HfApi

# %%
from huggingface_hub import ModelSearchArguments, DatasetSearchArguments

# %%
from prefect.client import Secret

# %%
import psycopg2

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

# %% [markdown]
# # Add some configuration

# %%
dir(pd.options.display)
# Out:
# ['chop_threshold',
#  'colheader_justify',
#  'date_dayfirst',
#  'date_yearfirst',
#  'encoding',
#  'expand_frame_repr',
#  'float_format',
#  'html',
#  'large_repr',
#  'max_categories',
#  'max_columns',
#  'max_colwidth',
#  'max_dir_items',
#  'max_info_columns',
#  'max_info_rows',
#  'max_rows',
#  'max_seq_items',
#  'memory_usage',
#  'min_rows',
#  'multi_sparse',
#  'notebook_repr_html',
#  'pprint_nest_depth',
#  'precision',
#  'show_dimensions',
#  'unicode',
#  'width']

# %%
pd.options.display.max_rows = 200
pd.options.display.max_colwidth = None

# %%
n = 20

# %% [markdown]
# # Get data from Hugging Face

# %%
api = HfApi()

# %%
hugging_face_models = list(iter(api.list_models()))
hugging_face_datasets = list(iter(api.list_datasets()))

# %%
print(len(hugging_face_models))
print(len(hugging_face_datasets))
# Out:
# 216433
# 38047

# %%
for i in range(len(hugging_face_models)):
    hugging_face_models[i] = hugging_face_models[i].__dict__

# %%
for i in range(len(hugging_face_datasets)):
    hugging_face_datasets[i] = hugging_face_datasets[i].__dict__

# %%
hugging_face_models_json = json.dumps(hugging_face_models)
hugging_face_datasets_json = json.dumps(hugging_face_datasets)

# %% [markdown]
# # Hugging Face Models

# %%
models_slice_df = pd.read_json(hugging_face_models_json)

# %%
models_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)
# Out:
#                                         modelId  sha  lastModified
# 77446            runwayml/stable-diffusion-v1-5  NaN           NaN  \
# 63900             CompVis/stable-diffusion-v1-4  NaN           NaN
# 43855                          bigscience/bloom  NaN           NaN
# 92772                 WarriorMama777/OrangeMixs  NaN           NaN
# 127789                    lllyasviel/ControlNet  NaN           NaN
# 93946          stabilityai/stable-diffusion-2-1  NaN           NaN
# 82911                    prompthero/openjourney  NaN           NaN
# 63885   CompVis/stable-diffusion-v-1-4-original  NaN           NaN
# 112812                     andite/anything-v4.0  NaN           NaN
# 149336                         THUDM/chatglm-6b  NaN           NaN
# 65434                   hakurei/waifu-diffusion  NaN           NaN
# 172383                  databricks/dolly-v2-12b  NaN           NaN
# 182780                        bigcode/starcoder  NaN           NaN
# 87893            stabilityai/stable-diffusion-2  NaN           NaN
# 173454               lllyasviel/ControlNet-v1-1  NaN           NaN
# 124085                    gsdf/Counterfeit-V2.5  NaN           NaN
# 106874    dreamlike-art/dreamlike-photoreal-2.0  NaN           NaN
# 130983     webui/ControlNet-modules-safetensors  NaN           NaN
# 76624      runwayml/stable-diffusion-inpainting  NaN           NaN
# 2228                        EleutherAI/gpt-j-6b  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      tags
# 77446                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]  \
# 63900                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 43855   [pytorch, tensorboard, safetensors, bloom, text-generation, ak, ar, as, bm, bn, ca, code, en, es, eu, fon, fr, gu, hi, id, ig, ki, kn, lg, ln, ml, mr, ne, nso, ny, or, pa, pt, rn, rw, sn, st, sw, ta, te, tn, ts, tum, tw, ur, vi, wo, xh, yo, zh, zu, arxiv:2211.05100, arxiv:1909.08053, arxiv:2110.02861, arxiv:2108.12409, doi:10.57967/hf/0003, transformers, license:bigscience-bloom-rail-1.0, model-index, co2_eq_emissions, has_space]
# 92772                                                                                                                                                                                                                                                                                                                                 [diffusers, dataset:Nerfgun3/bad_prompt, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 127789                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 93946                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2112.10752, arxiv:2202.00512, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 82911                                                                                                                                                                                                                                                                                                                                             [diffusers, safetensors, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 63885                                                                                                                                                                                                                                                                               [arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 112812                                                                                                                                                                                                                                                                                                                             [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 149336                                                                                                                                                                                                                                                                                                                                                [pytorch, chatglm, zh, en, arxiv:2103.10360, arxiv:2210.02414, transformers, glm, thudm, has_space]
# 65434                                                                                                                                                                                                                                                                                                                                                          [diffusers, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 172383                                                                                                                                                                                                                                                                                                                            [pytorch, gpt_neox, text-generation, en, dataset:databricks/databricks-dolly-15k, transformers, license:mit, has_space]
# 182780                                                                                                                                                                                                                           [pytorch, gpt_bigcode, text-generation, dataset:bigcode/the-stack-dedup, arxiv:1911.02150, arxiv:2205.14135, arxiv:2207.14255, arxiv:2305.06161, transformers, code, license:bigcode-openrail-m, model-index, has_space]
# 87893                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2202.00512, arxiv:2112.10752, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 173454                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 124085                                                                                                                                                                                                                                                                                                                                 [diffusers, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 106874                                                                                                                                                                                                                                                                                                                  [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, photorealistic, photoreal, license:other, has_space]
# 130983                                                                                                                                                                                                                                                                                                                                                                                                                                        [has_space]
# 76624                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 2228                                                                                                                                                                                                                                                                                          [pytorch, tf, jax, gptj, text-generation, en, dataset:the_pile, arxiv:2104.09864, arxiv:2101.00027, transformers, causal-lm, license:apache-2.0, has_space]
#
#            pipeline_tag siblings  private  author  config  securityStatus
# 77446     text-to-image       []    False     NaN     NaN             NaN  \
# 63900     text-to-image       []    False     NaN     NaN             NaN
# 43855   text-generation       []    False     NaN     NaN             NaN
# 92772     text-to-image       []    False     NaN     NaN             NaN
# 127789             None       []    False     NaN     NaN             NaN
# 93946     text-to-image       []    False     NaN     NaN             NaN
# 82911     text-to-image       []    False     NaN     NaN             NaN
# 63885     text-to-image       []    False     NaN     NaN             NaN
# 112812    text-to-image       []    False     NaN     NaN             NaN
# 149336             None       []    False     NaN     NaN             NaN
# 65434     text-to-image       []    False     NaN     NaN             NaN
# 172383  text-generation       []    False     NaN     NaN             NaN
# 182780  text-generation       []    False     NaN     NaN             NaN
# 87893     text-to-image       []    False     NaN     NaN             NaN
# 173454             None       []    False     NaN     NaN             NaN
# 124085    text-to-image       []    False     NaN     NaN             NaN
# 106874    text-to-image       []    False     NaN     NaN             NaN
# 130983             None       []    False     NaN     NaN             NaN
# 76624     text-to-image       []    False     NaN     NaN             NaN
# 2228    text-generation       []    False     NaN     NaN             NaN
#
#                              _id                                       id
# 77446   63508a7bfc22005c1aae0266           runwayml/stable-diffusion-v1-5  \
# 63900   6300e0f58a4db6e9052953a8            CompVis/stable-diffusion-v1-4
# 43855   62862fbd504d37700308a82e                         bigscience/bloom
# 92772   638cac3a61eb5101751a23c4                WarriorMama777/OrangeMixs
# 127789  63e3ef298de575a15a63c2b1                    lllyasviel/ControlNet
# 93946   638f7ae36c25af4071044105         stabilityai/stable-diffusion-2-1
# 82911   636a251a2ca1d75cb49109ee                   prompthero/openjourney
# 63885   63009e8b79c5ddbc6cf69877  CompVis/stable-diffusion-v-1-4-original
# 112812  63c1595e94b28327f0e821e8                     andite/anything-v4.0
# 149336  640f4f1409c94e1d9bca3ffc                         THUDM/chatglm-6b
# 65434   630d75d18e3ff0c723329fc2                  hakurei/waifu-diffusion
# 172383  6435868e57c3f4b161f4fb13                  databricks/dolly-v2-12b
# 182780  644677e41173e85ac7f10745                        bigcode/starcoder
# 87893   637e09faaa60aba6d5a38fdc           stabilityai/stable-diffusion-2
# 173454  6437337f535846fc73640937               lllyasviel/ControlNet-v1-1
# 124085  63dbc263057a688a88c29b14                    gsdf/Counterfeit-V2.5
# 106874  63b4ec14f468cca7589f4de9    dreamlike-art/dreamlike-photoreal-2.0
# 130983  63ebf4a1308bd1f7fcb9ccbc     webui/ControlNet-modules-safetensors
# 76624   634cc280741a5e3788692687     runwayml/stable-diffusion-inpainting
# 2228    621ffdc036468d709f1753ba                      EleutherAI/gpt-j-6b
#
#         likes  downloads
# 77446    7948    2453705
# 63900    5560     980801
# 43855    3592      24011
# 92772    3028       6839
# 127789   2898          0
# 93946    2598     346410
# 82911    2576     639189
# 63885    2363          0
# 112812   2241      71668
# 149336   2110     736137
# 65434    2110     313648
# 172383   1736      69477
# 182780   1733      57631
# 87893    1516     112180
# 173454   1350          0
# 124085   1326      19227
# 106874   1309     188983
# 130983   1209          0
# 76624    1159     327951
# 2228     1125     414899

# %%
models_slice_df.fillna(value={"pipeline_tag": "unknown-tag"}, inplace=True)

# %%
models_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)
# Out:
#                                         modelId  sha  lastModified
# 77446            runwayml/stable-diffusion-v1-5  NaN           NaN  \
# 63900             CompVis/stable-diffusion-v1-4  NaN           NaN
# 43855                          bigscience/bloom  NaN           NaN
# 92772                 WarriorMama777/OrangeMixs  NaN           NaN
# 127789                    lllyasviel/ControlNet  NaN           NaN
# 93946          stabilityai/stable-diffusion-2-1  NaN           NaN
# 82911                    prompthero/openjourney  NaN           NaN
# 63885   CompVis/stable-diffusion-v-1-4-original  NaN           NaN
# 112812                     andite/anything-v4.0  NaN           NaN
# 149336                         THUDM/chatglm-6b  NaN           NaN
# 65434                   hakurei/waifu-diffusion  NaN           NaN
# 172383                  databricks/dolly-v2-12b  NaN           NaN
# 182780                        bigcode/starcoder  NaN           NaN
# 87893            stabilityai/stable-diffusion-2  NaN           NaN
# 173454               lllyasviel/ControlNet-v1-1  NaN           NaN
# 124085                    gsdf/Counterfeit-V2.5  NaN           NaN
# 106874    dreamlike-art/dreamlike-photoreal-2.0  NaN           NaN
# 130983     webui/ControlNet-modules-safetensors  NaN           NaN
# 76624      runwayml/stable-diffusion-inpainting  NaN           NaN
# 2228                        EleutherAI/gpt-j-6b  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      tags
# 77446                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]  \
# 63900                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 43855   [pytorch, tensorboard, safetensors, bloom, text-generation, ak, ar, as, bm, bn, ca, code, en, es, eu, fon, fr, gu, hi, id, ig, ki, kn, lg, ln, ml, mr, ne, nso, ny, or, pa, pt, rn, rw, sn, st, sw, ta, te, tn, ts, tum, tw, ur, vi, wo, xh, yo, zh, zu, arxiv:2211.05100, arxiv:1909.08053, arxiv:2110.02861, arxiv:2108.12409, doi:10.57967/hf/0003, transformers, license:bigscience-bloom-rail-1.0, model-index, co2_eq_emissions, has_space]
# 92772                                                                                                                                                                                                                                                                                                                                 [diffusers, dataset:Nerfgun3/bad_prompt, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 127789                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 93946                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2112.10752, arxiv:2202.00512, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 82911                                                                                                                                                                                                                                                                                                                                             [diffusers, safetensors, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 63885                                                                                                                                                                                                                                                                               [arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 112812                                                                                                                                                                                                                                                                                                                             [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 149336                                                                                                                                                                                                                                                                                                                                                [pytorch, chatglm, zh, en, arxiv:2103.10360, arxiv:2210.02414, transformers, glm, thudm, has_space]
# 65434                                                                                                                                                                                                                                                                                                                                                          [diffusers, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 172383                                                                                                                                                                                                                                                                                                                            [pytorch, gpt_neox, text-generation, en, dataset:databricks/databricks-dolly-15k, transformers, license:mit, has_space]
# 182780                                                                                                                                                                                                                           [pytorch, gpt_bigcode, text-generation, dataset:bigcode/the-stack-dedup, arxiv:1911.02150, arxiv:2205.14135, arxiv:2207.14255, arxiv:2305.06161, transformers, code, license:bigcode-openrail-m, model-index, has_space]
# 87893                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2202.00512, arxiv:2112.10752, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 173454                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 124085                                                                                                                                                                                                                                                                                                                                 [diffusers, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 106874                                                                                                                                                                                                                                                                                                                  [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, photorealistic, photoreal, license:other, has_space]
# 130983                                                                                                                                                                                                                                                                                                                                                                                                                                        [has_space]
# 76624                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 2228                                                                                                                                                                                                                                                                                          [pytorch, tf, jax, gptj, text-generation, en, dataset:the_pile, arxiv:2104.09864, arxiv:2101.00027, transformers, causal-lm, license:apache-2.0, has_space]
#
#            pipeline_tag siblings  private  author  config  securityStatus
# 77446     text-to-image       []    False     NaN     NaN             NaN  \
# 63900     text-to-image       []    False     NaN     NaN             NaN
# 43855   text-generation       []    False     NaN     NaN             NaN
# 92772     text-to-image       []    False     NaN     NaN             NaN
# 127789      unknown-tag       []    False     NaN     NaN             NaN
# 93946     text-to-image       []    False     NaN     NaN             NaN
# 82911     text-to-image       []    False     NaN     NaN             NaN
# 63885     text-to-image       []    False     NaN     NaN             NaN
# 112812    text-to-image       []    False     NaN     NaN             NaN
# 149336      unknown-tag       []    False     NaN     NaN             NaN
# 65434     text-to-image       []    False     NaN     NaN             NaN
# 172383  text-generation       []    False     NaN     NaN             NaN
# 182780  text-generation       []    False     NaN     NaN             NaN
# 87893     text-to-image       []    False     NaN     NaN             NaN
# 173454      unknown-tag       []    False     NaN     NaN             NaN
# 124085    text-to-image       []    False     NaN     NaN             NaN
# 106874    text-to-image       []    False     NaN     NaN             NaN
# 130983      unknown-tag       []    False     NaN     NaN             NaN
# 76624     text-to-image       []    False     NaN     NaN             NaN
# 2228    text-generation       []    False     NaN     NaN             NaN
#
#                              _id                                       id
# 77446   63508a7bfc22005c1aae0266           runwayml/stable-diffusion-v1-5  \
# 63900   6300e0f58a4db6e9052953a8            CompVis/stable-diffusion-v1-4
# 43855   62862fbd504d37700308a82e                         bigscience/bloom
# 92772   638cac3a61eb5101751a23c4                WarriorMama777/OrangeMixs
# 127789  63e3ef298de575a15a63c2b1                    lllyasviel/ControlNet
# 93946   638f7ae36c25af4071044105         stabilityai/stable-diffusion-2-1
# 82911   636a251a2ca1d75cb49109ee                   prompthero/openjourney
# 63885   63009e8b79c5ddbc6cf69877  CompVis/stable-diffusion-v-1-4-original
# 112812  63c1595e94b28327f0e821e8                     andite/anything-v4.0
# 149336  640f4f1409c94e1d9bca3ffc                         THUDM/chatglm-6b
# 65434   630d75d18e3ff0c723329fc2                  hakurei/waifu-diffusion
# 172383  6435868e57c3f4b161f4fb13                  databricks/dolly-v2-12b
# 182780  644677e41173e85ac7f10745                        bigcode/starcoder
# 87893   637e09faaa60aba6d5a38fdc           stabilityai/stable-diffusion-2
# 173454  6437337f535846fc73640937               lllyasviel/ControlNet-v1-1
# 124085  63dbc263057a688a88c29b14                    gsdf/Counterfeit-V2.5
# 106874  63b4ec14f468cca7589f4de9    dreamlike-art/dreamlike-photoreal-2.0
# 130983  63ebf4a1308bd1f7fcb9ccbc     webui/ControlNet-modules-safetensors
# 76624   634cc280741a5e3788692687     runwayml/stable-diffusion-inpainting
# 2228    621ffdc036468d709f1753ba                      EleutherAI/gpt-j-6b
#
#         likes  downloads
# 77446    7948    2453705
# 63900    5560     980801
# 43855    3592      24011
# 92772    3028       6839
# 127789   2898          0
# 93946    2598     346410
# 82911    2576     639189
# 63885    2363          0
# 112812   2241      71668
# 149336   2110     736137
# 65434    2110     313648
# 172383   1736      69477
# 182780   1733      57631
# 87893    1516     112180
# 173454   1350          0
# 124085   1326      19227
# 106874   1309     188983
# 130983   1209          0
# 76624    1159     327951
# 2228     1125     414899

# %%
models_slice_df["author"] = models_slice_df.modelId.apply(lambda x: x.split("/")[0] if "/" in x else "unknown-author")

# %%
models_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)
# Out:
#                                         modelId  sha  lastModified
# 77446            runwayml/stable-diffusion-v1-5  NaN           NaN  \
# 63900             CompVis/stable-diffusion-v1-4  NaN           NaN
# 43855                          bigscience/bloom  NaN           NaN
# 92772                 WarriorMama777/OrangeMixs  NaN           NaN
# 127789                    lllyasviel/ControlNet  NaN           NaN
# 93946          stabilityai/stable-diffusion-2-1  NaN           NaN
# 82911                    prompthero/openjourney  NaN           NaN
# 63885   CompVis/stable-diffusion-v-1-4-original  NaN           NaN
# 112812                     andite/anything-v4.0  NaN           NaN
# 149336                         THUDM/chatglm-6b  NaN           NaN
# 65434                   hakurei/waifu-diffusion  NaN           NaN
# 172383                  databricks/dolly-v2-12b  NaN           NaN
# 182780                        bigcode/starcoder  NaN           NaN
# 87893            stabilityai/stable-diffusion-2  NaN           NaN
# 173454               lllyasviel/ControlNet-v1-1  NaN           NaN
# 124085                    gsdf/Counterfeit-V2.5  NaN           NaN
# 106874    dreamlike-art/dreamlike-photoreal-2.0  NaN           NaN
# 130983     webui/ControlNet-modules-safetensors  NaN           NaN
# 76624      runwayml/stable-diffusion-inpainting  NaN           NaN
# 2228                        EleutherAI/gpt-j-6b  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      tags
# 77446                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]  \
# 63900                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 43855   [pytorch, tensorboard, safetensors, bloom, text-generation, ak, ar, as, bm, bn, ca, code, en, es, eu, fon, fr, gu, hi, id, ig, ki, kn, lg, ln, ml, mr, ne, nso, ny, or, pa, pt, rn, rw, sn, st, sw, ta, te, tn, ts, tum, tw, ur, vi, wo, xh, yo, zh, zu, arxiv:2211.05100, arxiv:1909.08053, arxiv:2110.02861, arxiv:2108.12409, doi:10.57967/hf/0003, transformers, license:bigscience-bloom-rail-1.0, model-index, co2_eq_emissions, has_space]
# 92772                                                                                                                                                                                                                                                                                                                                 [diffusers, dataset:Nerfgun3/bad_prompt, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 127789                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 93946                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2112.10752, arxiv:2202.00512, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 82911                                                                                                                                                                                                                                                                                                                                             [diffusers, safetensors, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 63885                                                                                                                                                                                                                                                                               [arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 112812                                                                                                                                                                                                                                                                                                                             [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 149336                                                                                                                                                                                                                                                                                                                                                [pytorch, chatglm, zh, en, arxiv:2103.10360, arxiv:2210.02414, transformers, glm, thudm, has_space]
# 65434                                                                                                                                                                                                                                                                                                                                                          [diffusers, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 172383                                                                                                                                                                                                                                                                                                                            [pytorch, gpt_neox, text-generation, en, dataset:databricks/databricks-dolly-15k, transformers, license:mit, has_space]
# 182780                                                                                                                                                                                                                           [pytorch, gpt_bigcode, text-generation, dataset:bigcode/the-stack-dedup, arxiv:1911.02150, arxiv:2205.14135, arxiv:2207.14255, arxiv:2305.06161, transformers, code, license:bigcode-openrail-m, model-index, has_space]
# 87893                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2202.00512, arxiv:2112.10752, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 173454                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 124085                                                                                                                                                                                                                                                                                                                                 [diffusers, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 106874                                                                                                                                                                                                                                                                                                                  [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, photorealistic, photoreal, license:other, has_space]
# 130983                                                                                                                                                                                                                                                                                                                                                                                                                                        [has_space]
# 76624                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 2228                                                                                                                                                                                                                                                                                          [pytorch, tf, jax, gptj, text-generation, en, dataset:the_pile, arxiv:2104.09864, arxiv:2101.00027, transformers, causal-lm, license:apache-2.0, has_space]
#
#            pipeline_tag siblings  private          author  config
# 77446     text-to-image       []    False        runwayml     NaN  \
# 63900     text-to-image       []    False         CompVis     NaN
# 43855   text-generation       []    False      bigscience     NaN
# 92772     text-to-image       []    False  WarriorMama777     NaN
# 127789      unknown-tag       []    False      lllyasviel     NaN
# 93946     text-to-image       []    False     stabilityai     NaN
# 82911     text-to-image       []    False      prompthero     NaN
# 63885     text-to-image       []    False         CompVis     NaN
# 112812    text-to-image       []    False          andite     NaN
# 149336      unknown-tag       []    False           THUDM     NaN
# 65434     text-to-image       []    False         hakurei     NaN
# 172383  text-generation       []    False      databricks     NaN
# 182780  text-generation       []    False         bigcode     NaN
# 87893     text-to-image       []    False     stabilityai     NaN
# 173454      unknown-tag       []    False      lllyasviel     NaN
# 124085    text-to-image       []    False            gsdf     NaN
# 106874    text-to-image       []    False   dreamlike-art     NaN
# 130983      unknown-tag       []    False           webui     NaN
# 76624     text-to-image       []    False        runwayml     NaN
# 2228    text-generation       []    False      EleutherAI     NaN
#
#         securityStatus                       _id
# 77446              NaN  63508a7bfc22005c1aae0266  \
# 63900              NaN  6300e0f58a4db6e9052953a8
# 43855              NaN  62862fbd504d37700308a82e
# 92772              NaN  638cac3a61eb5101751a23c4
# 127789             NaN  63e3ef298de575a15a63c2b1
# 93946              NaN  638f7ae36c25af4071044105
# 82911              NaN  636a251a2ca1d75cb49109ee
# 63885              NaN  63009e8b79c5ddbc6cf69877
# 112812             NaN  63c1595e94b28327f0e821e8
# 149336             NaN  640f4f1409c94e1d9bca3ffc
# 65434              NaN  630d75d18e3ff0c723329fc2
# 172383             NaN  6435868e57c3f4b161f4fb13
# 182780             NaN  644677e41173e85ac7f10745
# 87893              NaN  637e09faaa60aba6d5a38fdc
# 173454             NaN  6437337f535846fc73640937
# 124085             NaN  63dbc263057a688a88c29b14
# 106874             NaN  63b4ec14f468cca7589f4de9
# 130983             NaN  63ebf4a1308bd1f7fcb9ccbc
# 76624              NaN  634cc280741a5e3788692687
# 2228               NaN  621ffdc036468d709f1753ba
#
#                                              id  likes  downloads
# 77446            runwayml/stable-diffusion-v1-5   7948    2453705
# 63900             CompVis/stable-diffusion-v1-4   5560     980801
# 43855                          bigscience/bloom   3592      24011
# 92772                 WarriorMama777/OrangeMixs   3028       6839
# 127789                    lllyasviel/ControlNet   2898          0
# 93946          stabilityai/stable-diffusion-2-1   2598     346410
# 82911                    prompthero/openjourney   2576     639189
# 63885   CompVis/stable-diffusion-v-1-4-original   2363          0
# 112812                     andite/anything-v4.0   2241      71668
# 149336                         THUDM/chatglm-6b   2110     736137
# 65434                   hakurei/waifu-diffusion   2110     313648
# 172383                  databricks/dolly-v2-12b   1736      69477
# 182780                        bigcode/starcoder   1733      57631
# 87893            stabilityai/stable-diffusion-2   1516     112180
# 173454               lllyasviel/ControlNet-v1-1   1350          0
# 124085                    gsdf/Counterfeit-V2.5   1326      19227
# 106874    dreamlike-art/dreamlike-photoreal-2.0   1309     188983
# 130983     webui/ControlNet-modules-safetensors   1209          0
# 76624      runwayml/stable-diffusion-inpainting   1159     327951
# 2228                        EleutherAI/gpt-j-6b   1125     414899

# %%
models_slice_df["datasets"] = models_slice_df.tags.apply(lambda tags_array: [item for item in tags_array if "dataset:" in item])

# %%
models_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)
# Out:
#                                         modelId  sha  lastModified
# 77446            runwayml/stable-diffusion-v1-5  NaN           NaN  \
# 63900             CompVis/stable-diffusion-v1-4  NaN           NaN
# 43855                          bigscience/bloom  NaN           NaN
# 92772                 WarriorMama777/OrangeMixs  NaN           NaN
# 127789                    lllyasviel/ControlNet  NaN           NaN
# 93946          stabilityai/stable-diffusion-2-1  NaN           NaN
# 82911                    prompthero/openjourney  NaN           NaN
# 63885   CompVis/stable-diffusion-v-1-4-original  NaN           NaN
# 112812                     andite/anything-v4.0  NaN           NaN
# 149336                         THUDM/chatglm-6b  NaN           NaN
# 65434                   hakurei/waifu-diffusion  NaN           NaN
# 172383                  databricks/dolly-v2-12b  NaN           NaN
# 182780                        bigcode/starcoder  NaN           NaN
# 87893            stabilityai/stable-diffusion-2  NaN           NaN
# 173454               lllyasviel/ControlNet-v1-1  NaN           NaN
# 124085                    gsdf/Counterfeit-V2.5  NaN           NaN
# 106874    dreamlike-art/dreamlike-photoreal-2.0  NaN           NaN
# 130983     webui/ControlNet-modules-safetensors  NaN           NaN
# 76624      runwayml/stable-diffusion-inpainting  NaN           NaN
# 2228                        EleutherAI/gpt-j-6b  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      tags
# 77446                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]  \
# 63900                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 43855   [pytorch, tensorboard, safetensors, bloom, text-generation, ak, ar, as, bm, bn, ca, code, en, es, eu, fon, fr, gu, hi, id, ig, ki, kn, lg, ln, ml, mr, ne, nso, ny, or, pa, pt, rn, rw, sn, st, sw, ta, te, tn, ts, tum, tw, ur, vi, wo, xh, yo, zh, zu, arxiv:2211.05100, arxiv:1909.08053, arxiv:2110.02861, arxiv:2108.12409, doi:10.57967/hf/0003, transformers, license:bigscience-bloom-rail-1.0, model-index, co2_eq_emissions, has_space]
# 92772                                                                                                                                                                                                                                                                                                                                 [diffusers, dataset:Nerfgun3/bad_prompt, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 127789                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 93946                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2112.10752, arxiv:2202.00512, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 82911                                                                                                                                                                                                                                                                                                                                             [diffusers, safetensors, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 63885                                                                                                                                                                                                                                                                               [arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 112812                                                                                                                                                                                                                                                                                                                             [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 149336                                                                                                                                                                                                                                                                                                                                                [pytorch, chatglm, zh, en, arxiv:2103.10360, arxiv:2210.02414, transformers, glm, thudm, has_space]
# 65434                                                                                                                                                                                                                                                                                                                                                          [diffusers, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 172383                                                                                                                                                                                                                                                                                                                            [pytorch, gpt_neox, text-generation, en, dataset:databricks/databricks-dolly-15k, transformers, license:mit, has_space]
# 182780                                                                                                                                                                                                                           [pytorch, gpt_bigcode, text-generation, dataset:bigcode/the-stack-dedup, arxiv:1911.02150, arxiv:2205.14135, arxiv:2207.14255, arxiv:2305.06161, transformers, code, license:bigcode-openrail-m, model-index, has_space]
# 87893                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2202.00512, arxiv:2112.10752, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 173454                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 124085                                                                                                                                                                                                                                                                                                                                 [diffusers, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 106874                                                                                                                                                                                                                                                                                                                  [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, photorealistic, photoreal, license:other, has_space]
# 130983                                                                                                                                                                                                                                                                                                                                                                                                                                        [has_space]
# 76624                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 2228                                                                                                                                                                                                                                                                                          [pytorch, tf, jax, gptj, text-generation, en, dataset:the_pile, arxiv:2104.09864, arxiv:2101.00027, transformers, causal-lm, license:apache-2.0, has_space]
#
#            pipeline_tag siblings  private          author  config
# 77446     text-to-image       []    False        runwayml     NaN  \
# 63900     text-to-image       []    False         CompVis     NaN
# 43855   text-generation       []    False      bigscience     NaN
# 92772     text-to-image       []    False  WarriorMama777     NaN
# 127789      unknown-tag       []    False      lllyasviel     NaN
# 93946     text-to-image       []    False     stabilityai     NaN
# 82911     text-to-image       []    False      prompthero     NaN
# 63885     text-to-image       []    False         CompVis     NaN
# 112812    text-to-image       []    False          andite     NaN
# 149336      unknown-tag       []    False           THUDM     NaN
# 65434     text-to-image       []    False         hakurei     NaN
# 172383  text-generation       []    False      databricks     NaN
# 182780  text-generation       []    False         bigcode     NaN
# 87893     text-to-image       []    False     stabilityai     NaN
# 173454      unknown-tag       []    False      lllyasviel     NaN
# 124085    text-to-image       []    False            gsdf     NaN
# 106874    text-to-image       []    False   dreamlike-art     NaN
# 130983      unknown-tag       []    False           webui     NaN
# 76624     text-to-image       []    False        runwayml     NaN
# 2228    text-generation       []    False      EleutherAI     NaN
#
#         securityStatus                       _id
# 77446              NaN  63508a7bfc22005c1aae0266  \
# 63900              NaN  6300e0f58a4db6e9052953a8
# 43855              NaN  62862fbd504d37700308a82e
# 92772              NaN  638cac3a61eb5101751a23c4
# 127789             NaN  63e3ef298de575a15a63c2b1
# 93946              NaN  638f7ae36c25af4071044105
# 82911              NaN  636a251a2ca1d75cb49109ee
# 63885              NaN  63009e8b79c5ddbc6cf69877
# 112812             NaN  63c1595e94b28327f0e821e8
# 149336             NaN  640f4f1409c94e1d9bca3ffc
# 65434              NaN  630d75d18e3ff0c723329fc2
# 172383             NaN  6435868e57c3f4b161f4fb13
# 182780             NaN  644677e41173e85ac7f10745
# 87893              NaN  637e09faaa60aba6d5a38fdc
# 173454             NaN  6437337f535846fc73640937
# 124085             NaN  63dbc263057a688a88c29b14
# 106874             NaN  63b4ec14f468cca7589f4de9
# 130983             NaN  63ebf4a1308bd1f7fcb9ccbc
# 76624              NaN  634cc280741a5e3788692687
# 2228               NaN  621ffdc036468d709f1753ba
#
#                                              id  likes  downloads
# 77446            runwayml/stable-diffusion-v1-5   7948    2453705  \
# 63900             CompVis/stable-diffusion-v1-4   5560     980801
# 43855                          bigscience/bloom   3592      24011
# 92772                 WarriorMama777/OrangeMixs   3028       6839
# 127789                    lllyasviel/ControlNet   2898          0
# 93946          stabilityai/stable-diffusion-2-1   2598     346410
# 82911                    prompthero/openjourney   2576     639189
# 63885   CompVis/stable-diffusion-v-1-4-original   2363          0
# 112812                     andite/anything-v4.0   2241      71668
# 149336                         THUDM/chatglm-6b   2110     736137
# 65434                   hakurei/waifu-diffusion   2110     313648
# 172383                  databricks/dolly-v2-12b   1736      69477
# 182780                        bigcode/starcoder   1733      57631
# 87893            stabilityai/stable-diffusion-2   1516     112180
# 173454               lllyasviel/ControlNet-v1-1   1350          0
# 124085                    gsdf/Counterfeit-V2.5   1326      19227
# 106874    dreamlike-art/dreamlike-photoreal-2.0   1309     188983
# 130983     webui/ControlNet-modules-safetensors   1209          0
# 76624      runwayml/stable-diffusion-inpainting   1159     327951
# 2228                        EleutherAI/gpt-j-6b   1125     414899
#
#                                          datasets
# 77446                                          []
# 63900                                          []
# 43855                                          []
# 92772               [dataset:Nerfgun3/bad_prompt]
# 127789                                         []
# 93946                                          []
# 82911                                          []
# 63885                                          []
# 112812                                         []
# 149336                                         []
# 65434                                          []
# 172383  [dataset:databricks/databricks-dolly-15k]
# 182780          [dataset:bigcode/the-stack-dedup]
# 87893                                          []
# 173454                                         []
# 124085                                         []
# 106874                                         []
# 130983                                         []
# 76624                                          []
# 2228                           [dataset:the_pile]

# %%
models_slice_df["has_space"] = models_slice_df.tags.apply(lambda tags_array: "has_space" in tags_array)

# %%
models_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)
# Out:
#                                         modelId  sha  lastModified
# 77446            runwayml/stable-diffusion-v1-5  NaN           NaN  \
# 63900             CompVis/stable-diffusion-v1-4  NaN           NaN
# 43855                          bigscience/bloom  NaN           NaN
# 92772                 WarriorMama777/OrangeMixs  NaN           NaN
# 127789                    lllyasviel/ControlNet  NaN           NaN
# 93946          stabilityai/stable-diffusion-2-1  NaN           NaN
# 82911                    prompthero/openjourney  NaN           NaN
# 63885   CompVis/stable-diffusion-v-1-4-original  NaN           NaN
# 112812                     andite/anything-v4.0  NaN           NaN
# 149336                         THUDM/chatglm-6b  NaN           NaN
# 65434                   hakurei/waifu-diffusion  NaN           NaN
# 172383                  databricks/dolly-v2-12b  NaN           NaN
# 182780                        bigcode/starcoder  NaN           NaN
# 87893            stabilityai/stable-diffusion-2  NaN           NaN
# 173454               lllyasviel/ControlNet-v1-1  NaN           NaN
# 124085                    gsdf/Counterfeit-V2.5  NaN           NaN
# 106874    dreamlike-art/dreamlike-photoreal-2.0  NaN           NaN
# 130983     webui/ControlNet-modules-safetensors  NaN           NaN
# 76624      runwayml/stable-diffusion-inpainting  NaN           NaN
# 2228                        EleutherAI/gpt-j-6b  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      tags
# 77446                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]  \
# 63900                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 43855   [pytorch, tensorboard, safetensors, bloom, text-generation, ak, ar, as, bm, bn, ca, code, en, es, eu, fon, fr, gu, hi, id, ig, ki, kn, lg, ln, ml, mr, ne, nso, ny, or, pa, pt, rn, rw, sn, st, sw, ta, te, tn, ts, tum, tw, ur, vi, wo, xh, yo, zh, zu, arxiv:2211.05100, arxiv:1909.08053, arxiv:2110.02861, arxiv:2108.12409, doi:10.57967/hf/0003, transformers, license:bigscience-bloom-rail-1.0, model-index, co2_eq_emissions, has_space]
# 92772                                                                                                                                                                                                                                                                                                                                 [diffusers, dataset:Nerfgun3/bad_prompt, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 127789                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 93946                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2112.10752, arxiv:2202.00512, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 82911                                                                                                                                                                                                                                                                                                                                             [diffusers, safetensors, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 63885                                                                                                                                                                                                                                                                               [arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 112812                                                                                                                                                                                                                                                                                                                             [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 149336                                                                                                                                                                                                                                                                                                                                                [pytorch, chatglm, zh, en, arxiv:2103.10360, arxiv:2210.02414, transformers, glm, thudm, has_space]
# 65434                                                                                                                                                                                                                                                                                                                                                          [diffusers, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 172383                                                                                                                                                                                                                                                                                                                            [pytorch, gpt_neox, text-generation, en, dataset:databricks/databricks-dolly-15k, transformers, license:mit, has_space]
# 182780                                                                                                                                                                                                                           [pytorch, gpt_bigcode, text-generation, dataset:bigcode/the-stack-dedup, arxiv:1911.02150, arxiv:2205.14135, arxiv:2207.14255, arxiv:2305.06161, transformers, code, license:bigcode-openrail-m, model-index, has_space]
# 87893                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2202.00512, arxiv:2112.10752, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 173454                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 124085                                                                                                                                                                                                                                                                                                                                 [diffusers, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 106874                                                                                                                                                                                                                                                                                                                  [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, photorealistic, photoreal, license:other, has_space]
# 130983                                                                                                                                                                                                                                                                                                                                                                                                                                        [has_space]
# 76624                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 2228                                                                                                                                                                                                                                                                                          [pytorch, tf, jax, gptj, text-generation, en, dataset:the_pile, arxiv:2104.09864, arxiv:2101.00027, transformers, causal-lm, license:apache-2.0, has_space]
#
#            pipeline_tag siblings  private          author  config
# 77446     text-to-image       []    False        runwayml     NaN  \
# 63900     text-to-image       []    False         CompVis     NaN
# 43855   text-generation       []    False      bigscience     NaN
# 92772     text-to-image       []    False  WarriorMama777     NaN
# 127789      unknown-tag       []    False      lllyasviel     NaN
# 93946     text-to-image       []    False     stabilityai     NaN
# 82911     text-to-image       []    False      prompthero     NaN
# 63885     text-to-image       []    False         CompVis     NaN
# 112812    text-to-image       []    False          andite     NaN
# 149336      unknown-tag       []    False           THUDM     NaN
# 65434     text-to-image       []    False         hakurei     NaN
# 172383  text-generation       []    False      databricks     NaN
# 182780  text-generation       []    False         bigcode     NaN
# 87893     text-to-image       []    False     stabilityai     NaN
# 173454      unknown-tag       []    False      lllyasviel     NaN
# 124085    text-to-image       []    False            gsdf     NaN
# 106874    text-to-image       []    False   dreamlike-art     NaN
# 130983      unknown-tag       []    False           webui     NaN
# 76624     text-to-image       []    False        runwayml     NaN
# 2228    text-generation       []    False      EleutherAI     NaN
#
#         securityStatus                       _id
# 77446              NaN  63508a7bfc22005c1aae0266  \
# 63900              NaN  6300e0f58a4db6e9052953a8
# 43855              NaN  62862fbd504d37700308a82e
# 92772              NaN  638cac3a61eb5101751a23c4
# 127789             NaN  63e3ef298de575a15a63c2b1
# 93946              NaN  638f7ae36c25af4071044105
# 82911              NaN  636a251a2ca1d75cb49109ee
# 63885              NaN  63009e8b79c5ddbc6cf69877
# 112812             NaN  63c1595e94b28327f0e821e8
# 149336             NaN  640f4f1409c94e1d9bca3ffc
# 65434              NaN  630d75d18e3ff0c723329fc2
# 172383             NaN  6435868e57c3f4b161f4fb13
# 182780             NaN  644677e41173e85ac7f10745
# 87893              NaN  637e09faaa60aba6d5a38fdc
# 173454             NaN  6437337f535846fc73640937
# 124085             NaN  63dbc263057a688a88c29b14
# 106874             NaN  63b4ec14f468cca7589f4de9
# 130983             NaN  63ebf4a1308bd1f7fcb9ccbc
# 76624              NaN  634cc280741a5e3788692687
# 2228               NaN  621ffdc036468d709f1753ba
#
#                                              id  likes  downloads
# 77446            runwayml/stable-diffusion-v1-5   7948    2453705  \
# 63900             CompVis/stable-diffusion-v1-4   5560     980801
# 43855                          bigscience/bloom   3592      24011
# 92772                 WarriorMama777/OrangeMixs   3028       6839
# 127789                    lllyasviel/ControlNet   2898          0
# 93946          stabilityai/stable-diffusion-2-1   2598     346410
# 82911                    prompthero/openjourney   2576     639189
# 63885   CompVis/stable-diffusion-v-1-4-original   2363          0
# 112812                     andite/anything-v4.0   2241      71668
# 149336                         THUDM/chatglm-6b   2110     736137
# 65434                   hakurei/waifu-diffusion   2110     313648
# 172383                  databricks/dolly-v2-12b   1736      69477
# 182780                        bigcode/starcoder   1733      57631
# 87893            stabilityai/stable-diffusion-2   1516     112180
# 173454               lllyasviel/ControlNet-v1-1   1350          0
# 124085                    gsdf/Counterfeit-V2.5   1326      19227
# 106874    dreamlike-art/dreamlike-photoreal-2.0   1309     188983
# 130983     webui/ControlNet-modules-safetensors   1209          0
# 76624      runwayml/stable-diffusion-inpainting   1159     327951
# 2228                        EleutherAI/gpt-j-6b   1125     414899
#
#                                          datasets  has_space
# 77446                                          []       True
# 63900                                          []       True
# 43855                                          []       True
# 92772               [dataset:Nerfgun3/bad_prompt]       True
# 127789                                         []       True
# 93946                                          []       True
# 82911                                          []       True
# 63885                                          []       True
# 112812                                         []       True
# 149336                                         []       True
# 65434                                          []       True
# 172383  [dataset:databricks/databricks-dolly-15k]       True
# 182780          [dataset:bigcode/the-stack-dedup]       True
# 87893                                          []       True
# 173454                                         []       True
# 124085                                         []       True
# 106874                                         []       True
# 130983                                         []       True
# 76624                                          []       True
# 2228                           [dataset:the_pile]       True

# %%
models_slice_df["has_space"].value_counts()
# Out:
# has_space
# False    207779
# True       8654
# Name: count, dtype: int64

# %%
models_slice_df["pipeline_tag"].value_counts()
# Out:
# pipeline_tag
# unknown-tag                       92254
# text-classification               23520
# reinforcement-learning            21087
# text2text-generation              14101
# text-generation                   12601
# token-classification               9052
# automatic-speech-recognition       8381
# fill-mask                          7036
# question-answering                 4993
# text-to-image                      4354
# image-classification               3945
# feature-extraction                 3909
# conversational                     2178
# translation                        2125
# sentence-similarity                1958
# summarization                      1127
# unconditional-image-generation      681
# audio-classification                539
# object-detection                    429
# multiple-choice                     313
# text-to-speech                      291
# image-segmentation                  217
# audio-to-audio                      155
# image-to-text                       153
# tabular-classification              146
# video-classification                143
# zero-shot-classification            140
# zero-shot-image-classification      138
# image-to-image                      135
# tabular-regression                   78
# depth-estimation                     61
# table-question-answering             59
# document-question-answering          41
# visual-question-answering            40
# text-to-video                        27
# voice-activity-detection             11
# robotics                              6
# other                                 4
# graph-ml                              4
# time-series-forecasting               1
# Name: count, dtype: int64

# %%
domains = [
    "computer-vision",
    "natural-language-processing",
    "audio",
    "tabular",
    "multimodal",
    "reinforcement-learning",
    "unknown-domain",
    "time-series",
    "graph",
    "robotics"
]

# %%
task2domain = {
    "text-classification":            "natural-language-processing",
    "reinforcement-learning":         "reinforcement-learning",
    "text2text-generation":           "natural-language-processing",
    "text-generation":                "natural-language-processing",
    "token-classification":           "natural-language-processing",
    "automatic-speech-recognition":   "audio",
    "fill-mask":                      "natural-language-processing",
    "question-answering":             "natural-language-processing",
    "text-to-image":                  "multimodal",
    "feature-extraction":             "multimodal",
    "image-classification":           "computer-vision",
    "conversational":                 "natural-language-processing",
    "translation":                    "natural-language-processing",
    "sentence-similarity":            "natural-language-processing",
    "summarization":                  "natural-language-processing",
    "unconditional-image-generation": "computer-vision",
    "audio-classification":           "audio",
    "object-detection":               "computer-vision",
    "multiple-choice":                "unknown-domain",
    "text-to-speech":                 "audio",
    "image-segmentation":             "computer-vision",
    "audio-to-audio":                 "audio",
    "image-to-text":                  "multimodal",
    "tabular-classification":         "tabular",
    "zero-shot-image-classification": "computer-vision",
    "zero-shot-classification":       "natural-language-processing",
    "video-classification":           "computer-vision",
    "image-to-image":                 "computer-vision",
    "tabular-regression":             "tabular",
    "table-question-answering":       "natural-language-processing",
    "depth-estimation":               "computer-vision",
    "document-question-answering":    "multimodal",
    "text-to-video":                  "multimodal",
    "visual-question-answering":      "multimodal",
    "voice-activity-detection":       "audio",
    "robotics":                       "robotics",
    "other":                          "unknown-domain",
    "graph-ml":                       "graph",
    "time-series-forecasting":        "time-series"
}

# %%
models_slice_df["domain"] = models_slice_df.pipeline_tag.apply(lambda tag: task2domain.get(tag, "unknown-domain"))

# %%
models_slice_df["slice_datetime"] = datetime.now()

# %%
models_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)
# Out:
#                                         modelId  sha  lastModified
# 77446            runwayml/stable-diffusion-v1-5  NaN           NaN  \
# 63900             CompVis/stable-diffusion-v1-4  NaN           NaN
# 43855                          bigscience/bloom  NaN           NaN
# 92772                 WarriorMama777/OrangeMixs  NaN           NaN
# 127789                    lllyasviel/ControlNet  NaN           NaN
# 93946          stabilityai/stable-diffusion-2-1  NaN           NaN
# 82911                    prompthero/openjourney  NaN           NaN
# 63885   CompVis/stable-diffusion-v-1-4-original  NaN           NaN
# 112812                     andite/anything-v4.0  NaN           NaN
# 149336                         THUDM/chatglm-6b  NaN           NaN
# 65434                   hakurei/waifu-diffusion  NaN           NaN
# 172383                  databricks/dolly-v2-12b  NaN           NaN
# 182780                        bigcode/starcoder  NaN           NaN
# 87893            stabilityai/stable-diffusion-2  NaN           NaN
# 173454               lllyasviel/ControlNet-v1-1  NaN           NaN
# 124085                    gsdf/Counterfeit-V2.5  NaN           NaN
# 106874    dreamlike-art/dreamlike-photoreal-2.0  NaN           NaN
# 130983     webui/ControlNet-modules-safetensors  NaN           NaN
# 76624      runwayml/stable-diffusion-inpainting  NaN           NaN
# 2228                        EleutherAI/gpt-j-6b  NaN           NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                      tags
# 77446                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]  \
# 63900                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 43855   [pytorch, tensorboard, safetensors, bloom, text-generation, ak, ar, as, bm, bn, ca, code, en, es, eu, fon, fr, gu, hi, id, ig, ki, kn, lg, ln, ml, mr, ne, nso, ny, or, pa, pt, rn, rw, sn, st, sw, ta, te, tn, ts, tum, tw, ur, vi, wo, xh, yo, zh, zu, arxiv:2211.05100, arxiv:1909.08053, arxiv:2110.02861, arxiv:2108.12409, doi:10.57967/hf/0003, transformers, license:bigscience-bloom-rail-1.0, model-index, co2_eq_emissions, has_space]
# 92772                                                                                                                                                                                                                                                                                                                                 [diffusers, dataset:Nerfgun3/bad_prompt, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 127789                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 93946                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2112.10752, arxiv:2202.00512, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 82911                                                                                                                                                                                                                                                                                                                                             [diffusers, safetensors, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 63885                                                                                                                                                                                                                                                                               [arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 112812                                                                                                                                                                                                                                                                                                                             [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 149336                                                                                                                                                                                                                                                                                                                                                [pytorch, chatglm, zh, en, arxiv:2103.10360, arxiv:2210.02414, transformers, glm, thudm, has_space]
# 65434                                                                                                                                                                                                                                                                                                                                                          [diffusers, en, stable-diffusion, text-to-image, license:creativeml-openrail-m, has_space]
# 172383                                                                                                                                                                                                                                                                                                                            [pytorch, gpt_neox, text-generation, en, dataset:databricks/databricks-dolly-15k, transformers, license:mit, has_space]
# 182780                                                                                                                                                                                                                           [pytorch, gpt_bigcode, text-generation, dataset:bigcode/the-stack-dedup, arxiv:1911.02150, arxiv:2205.14135, arxiv:2207.14255, arxiv:2305.06161, transformers, code, license:bigcode-openrail-m, model-index, has_space]
# 87893                                                                                                                                                                                                                                                                                                                   [diffusers, arxiv:2202.00512, arxiv:2112.10752, arxiv:1910.09700, stable-diffusion, text-to-image, license:openrail++, has_space]
# 173454                                                                                                                                                                                                                                                                                                                                                                                                                      [license:openrail, has_space]
# 124085                                                                                                                                                                                                                                                                                                                                 [diffusers, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 106874                                                                                                                                                                                                                                                                                                                  [diffusers, en, stable-diffusion, stable-diffusion-diffusers, text-to-image, photorealistic, photoreal, license:other, has_space]
# 130983                                                                                                                                                                                                                                                                                                                                                                                                                                        [has_space]
# 76624                                                                                                                                                                                                                                        [diffusers, arxiv:2207.12598, arxiv:2112.10752, arxiv:2103.00020, arxiv:2205.11487, arxiv:1910.09700, stable-diffusion, stable-diffusion-diffusers, text-to-image, license:creativeml-openrail-m, has_space]
# 2228                                                                                                                                                                                                                                                                                          [pytorch, tf, jax, gptj, text-generation, en, dataset:the_pile, arxiv:2104.09864, arxiv:2101.00027, transformers, causal-lm, license:apache-2.0, has_space]
#
#            pipeline_tag siblings  private          author  config
# 77446     text-to-image       []    False        runwayml     NaN  \
# 63900     text-to-image       []    False         CompVis     NaN
# 43855   text-generation       []    False      bigscience     NaN
# 92772     text-to-image       []    False  WarriorMama777     NaN
# 127789      unknown-tag       []    False      lllyasviel     NaN
# 93946     text-to-image       []    False     stabilityai     NaN
# 82911     text-to-image       []    False      prompthero     NaN
# 63885     text-to-image       []    False         CompVis     NaN
# 112812    text-to-image       []    False          andite     NaN
# 149336      unknown-tag       []    False           THUDM     NaN
# 65434     text-to-image       []    False         hakurei     NaN
# 172383  text-generation       []    False      databricks     NaN
# 182780  text-generation       []    False         bigcode     NaN
# 87893     text-to-image       []    False     stabilityai     NaN
# 173454      unknown-tag       []    False      lllyasviel     NaN
# 124085    text-to-image       []    False            gsdf     NaN
# 106874    text-to-image       []    False   dreamlike-art     NaN
# 130983      unknown-tag       []    False           webui     NaN
# 76624     text-to-image       []    False        runwayml     NaN
# 2228    text-generation       []    False      EleutherAI     NaN
#
#         securityStatus                       _id
# 77446              NaN  63508a7bfc22005c1aae0266  \
# 63900              NaN  6300e0f58a4db6e9052953a8
# 43855              NaN  62862fbd504d37700308a82e
# 92772              NaN  638cac3a61eb5101751a23c4
# 127789             NaN  63e3ef298de575a15a63c2b1
# 93946              NaN  638f7ae36c25af4071044105
# 82911              NaN  636a251a2ca1d75cb49109ee
# 63885              NaN  63009e8b79c5ddbc6cf69877
# 112812             NaN  63c1595e94b28327f0e821e8
# 149336             NaN  640f4f1409c94e1d9bca3ffc
# 65434              NaN  630d75d18e3ff0c723329fc2
# 172383             NaN  6435868e57c3f4b161f4fb13
# 182780             NaN  644677e41173e85ac7f10745
# 87893              NaN  637e09faaa60aba6d5a38fdc
# 173454             NaN  6437337f535846fc73640937
# 124085             NaN  63dbc263057a688a88c29b14
# 106874             NaN  63b4ec14f468cca7589f4de9
# 130983             NaN  63ebf4a1308bd1f7fcb9ccbc
# 76624              NaN  634cc280741a5e3788692687
# 2228               NaN  621ffdc036468d709f1753ba
#
#                                              id  likes  downloads
# 77446            runwayml/stable-diffusion-v1-5   7948    2453705  \
# 63900             CompVis/stable-diffusion-v1-4   5560     980801
# 43855                          bigscience/bloom   3592      24011
# 92772                 WarriorMama777/OrangeMixs   3028       6839
# 127789                    lllyasviel/ControlNet   2898          0
# 93946          stabilityai/stable-diffusion-2-1   2598     346410
# 82911                    prompthero/openjourney   2576     639189
# 63885   CompVis/stable-diffusion-v-1-4-original   2363          0
# 112812                     andite/anything-v4.0   2241      71668
# 149336                         THUDM/chatglm-6b   2110     736137
# 65434                   hakurei/waifu-diffusion   2110     313648
# 172383                  databricks/dolly-v2-12b   1736      69477
# 182780                        bigcode/starcoder   1733      57631
# 87893            stabilityai/stable-diffusion-2   1516     112180
# 173454               lllyasviel/ControlNet-v1-1   1350          0
# 124085                    gsdf/Counterfeit-V2.5   1326      19227
# 106874    dreamlike-art/dreamlike-photoreal-2.0   1309     188983
# 130983     webui/ControlNet-modules-safetensors   1209          0
# 76624      runwayml/stable-diffusion-inpainting   1159     327951
# 2228                        EleutherAI/gpt-j-6b   1125     414899
#
#                                          datasets  has_space
# 77446                                          []       True  \
# 63900                                          []       True
# 43855                                          []       True
# 92772               [dataset:Nerfgun3/bad_prompt]       True
# 127789                                         []       True
# 93946                                          []       True
# 82911                                          []       True
# 63885                                          []       True
# 112812                                         []       True
# 149336                                         []       True
# 65434                                          []       True
# 172383  [dataset:databricks/databricks-dolly-15k]       True
# 182780          [dataset:bigcode/the-stack-dedup]       True
# 87893                                          []       True
# 173454                                         []       True
# 124085                                         []       True
# 106874                                         []       True
# 130983                                         []       True
# 76624                                          []       True
# 2228                           [dataset:the_pile]       True
#
#                              domain             slice_datetime
# 77446                    multimodal 2023-05-31 15:09:04.407835
# 63900                    multimodal 2023-05-31 15:09:04.407835
# 43855   natural-language-processing 2023-05-31 15:09:04.407835
# 92772                    multimodal 2023-05-31 15:09:04.407835
# 127789               unknown-domain 2023-05-31 15:09:04.407835
# 93946                    multimodal 2023-05-31 15:09:04.407835
# 82911                    multimodal 2023-05-31 15:09:04.407835
# 63885                    multimodal 2023-05-31 15:09:04.407835
# 112812                   multimodal 2023-05-31 15:09:04.407835
# 149336               unknown-domain 2023-05-31 15:09:04.407835
# 65434                    multimodal 2023-05-31 15:09:04.407835
# 172383  natural-language-processing 2023-05-31 15:09:04.407835
# 182780  natural-language-processing 2023-05-31 15:09:04.407835
# 87893                    multimodal 2023-05-31 15:09:04.407835
# 173454               unknown-domain 2023-05-31 15:09:04.407835
# 124085                   multimodal 2023-05-31 15:09:04.407835
# 106874                   multimodal 2023-05-31 15:09:04.407835
# 130983               unknown-domain 2023-05-31 15:09:04.407835
# 76624                    multimodal 2023-05-31 15:09:04.407835
# 2228    natural-language-processing 2023-05-31 15:09:04.407835

# %%
models_slice_df.dtypes
# Out:
# modelId                   object
# sha                      float64
# lastModified             float64
# tags                      object
# pipeline_tag              object
# siblings                  object
# private                     bool
# author                    object
# config                   float64
# securityStatus           float64
# _id                       object
# id                        object
# likes                      int64
# downloads                  int64
# datasets                  object
# has_space                   bool
# domain                    object
# slice_datetime    datetime64[ns]
# dtype: object

# %%
models_slice_df.siblings.value_counts()
# Out:
# siblings
# []    216433
# Name: count, dtype: int64

# %%
models_slice_df.sha.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
models_slice_df.lastModified.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
models_slice_df.private.value_counts()
# Out:
# private
# False    216433
# Name: count, dtype: int64

# %%
models_slice_df.config.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
models_slice_df.securityStatus.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
for col in models_slice_df.columns:
    print(col)
# Out:
# modelId
# sha
# lastModified
# tags
# pipeline_tag
# siblings
# private
# author
# config
# securityStatus
# _id
# id
# likes
# downloads
# datasets
# has_space
# domain
# slice_datetime

# %%
models_slice_df.isna().sum()
# Out:
# modelId                0
# sha               216433
# lastModified      216433
# tags                   0
# pipeline_tag           0
# siblings               0
# private                0
# author                 0
# config            216433
# securityStatus    216433
# _id                    0
# id                     0
# likes                  0
# downloads              0
# datasets               0
# has_space              0
# domain                 0
# slice_datetime         0
# dtype: int64

# %%
models_slice_df.rename(columns={col: col.lower() for col in models_slice_df.columns}, inplace=True)

# %%
for col in models_slice_df.columns:
    print(col)
# Out:
# modelid
# sha
# lastmodified
# tags
# pipeline_tag
# siblings
# private
# author
# config
# securitystatus
# _id
# id
# likes
# downloads
# datasets
# has_space
# domain
# slice_datetime

# %%
len(models_slice_df[(models_slice_df.pipeline_tag == "unknown-tag") & (models_slice_df.modelid.apply(lambda x: "gpt" in x.lower()))])
# Out:
# 2921

# %%
len(models_slice_df[(models_slice_df.pipeline_tag == "unknown-tag") & (models_slice_df.modelid.apply(lambda x: "bert" in x.lower()))])
# Out:
# 10314

# %%
len(models_slice_df[(models_slice_df.pipeline_tag == "unknown-tag")])
# Out:
# 92254

# %%
92254 - 10314 - 2921
# Out:
# 79019

# %%
plt.figure(figsize=(30, 20))
plt.rcParams.update({"font.size": 22})

models_slice_df["domain"].value_counts().plot(kind='barh')

plt.grid(True)
plt.show()

# %% [markdown]
# # Hugging Face Datasets

# %%
datasets_slice_df = pd.read_json(hugging_face_datasets_json)

# %%
datasets_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)

# %%
datasets_slice_df["tasks"] = datasets_slice_df.tags.apply(lambda tags_array: [item.split(":")[1] for item in tags_array if "task_categories:" in item])

# %%
datasets_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)

# %%
datasets_slice_df["size"] = datasets_slice_df.tags.apply(lambda tags_array: [item.split(":")[1] for item in tags_array if "size_categories:" in item])

# %%
datasets_slice_df.sort_values(["likes", "downloads"], ascending=False).head(n)

# %%
datasets_slice_df["slice_datetime"] = datetime.now()

# %%
datasets_slice_df.isna().sum()

# %%
for col in datasets_slice_df.columns:
    print(col)

# %%
datasets_slice_df.rename(columns={col: col.lower() for col in datasets_slice_df.columns}, inplace=True)

# %%
for col in datasets_slice_df.columns:
    print(col)

# %%
datasets_slice_df.rename(columns={"id": "datasetid"}, inplace=True)

# %%
for col in datasets_slice_df.columns:
    print(col)

# %% [markdown]
# # Check DB connection

# %%
db_host = Secret("DB_HOST").get()
db_user = Secret("DB_USER").get()
db_password = Secret("DB_PASSWORD").get()

# %%
# Or as a mix of both. The basic connection parameters are:

# - *dbname*: the database name
# - *database*: the database name (only as keyword argument)
# - *user*: user name used to authenticate
# - *password*: password used to authenticate
# - *host*: database host address (defaults to UNIX socket if not provided)
# - *port*: connection port number (defaults to 5432 if not provided)
con = psycopg2.connect(user=db_password, password=db_user, host=db_host, port=5432)

con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = con.cursor()

# %% [markdown]
# ## Create a database

# %%
cursor.execute("CREATE DATABASE RPD_5310")

# %%
cursor.execute("SELECT datname FROM pg_database WHERE datistemplate = false")

for row in cursor:
    print(row)

# %%
con.close()

# %% [markdown]
# ## Create tables

# %%
con = psycopg2.connect(user=db_password, password=db_user, host=db_host, port=5432, dbname="rpd_5310")

con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = con.cursor()

# %%
with open("create_tables.sql", "r") as file:
    cursor.execute(file.read())

# %%
cursor.execute("select * from pg_catalog.pg_tables where schemaname='public'")

for row in cursor:
    print(row)

# %%
template = "SELECT table_name, column_name, is_nullable, is_identity, data_type FROM information_schema.columns WHERE table_schema = 'public' AND table_name = '{}'"

# %%
cursor.execute(template.format("hugging_face_models"))

for row in cursor:
    print(row)

# %%
cursor.execute(template.format("hugging_face_models_daily_dynamics"))

for row in cursor:
    print(row)

# %%
cursor.execute(template.format("hugging_face_datasets"))

for row in cursor:
    print(row)

# %%
cursor.execute(template.format("hugging_face_datasets_daily_dynamics"))

for row in cursor:
    print(row)

# %%
con.close()

# %% [markdown]
# ## Drop a database

# %%
con = psycopg2.connect(user=db_password, password=db_user, host=db_host, port=5432)

con.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

cursor = con.cursor()

# %%
cursor.execute("DROP DATABASE RPD_5310")

# %%
cursor.execute("SELECT datname FROM pg_database WHERE datistemplate = false")

for row in cursor:
    print(row)

# %%
con.close()

# %% [markdown]
# # Write data to DB

# %%
engine = create_engine('postgresql://{}:{}@{}:5432/rpd_5310'.format(db_user, db_password, db_host))

# %%
models_df = pd.read_sql('hugging_face_models', engine)

# %%
models_df.head()

# %%
len(models_slice_df[~models_slice_df.modelid.isin(models_df.modelid)])

# %%
datasets_df = pd.read_sql('hugging_face_datasets', engine)

# %%
datasets_df.head()

# %%
len(datasets_slice_df[~datasets_slice_df.datasetid.isin(datasets_df.datasetid)])

# %%
models_mask = [col for col in models_df.columns if col not in ["likes", "downloads"]]
datasets_mask = [col for col in datasets_df.columns if col not in ["likes", "downloads"]]

# %%
if len(models_slice_df[~models_slice_df.modelid.isin(models_df.modelid)]) > 0:
    models_slice_df[~models_slice_df.modelid.isin(models_df.modelid)][models_mask].to_sql('hugging_face_models', engine, if_exists='append', index=False)

# %%
if len(datasets_slice_df[~datasets_slice_df.datasetid.isin(datasets_df.datasetid)]) > 0:
    datasets_slice_df[~datasets_slice_df.datasetid.isin(datasets_df.datasetid)][datasets_mask].to_sql('hugging_face_datasets', engine, if_exists='append', index=False)

# %%
models_mask = ["modelid", "likes", "downloads", "slice_datetime"]
datasets_mask = ["datasetid", "likes", "downloads", "slice_datetime"]

# %%
models_slice_df[models_mask].to_sql('hugging_face_models_daily_dynamics', engine, if_exists='append', index=False)

# %%
datasets_slice_df[datasets_mask].to_sql('hugging_face_datasets_daily_dynamics', engine, if_exists='append', index=False)

# %% [markdown]
# # Register and run Prefect flow

# %%
! prefect get projects

# %%
! prefect create project "RPD_5310" --description "This is the test project for task RPD-5310 (Getting data from HuggingFace about models and datasets)"

# %%
! prefect get projects

# %%
! prefect register --project RPD_5310 -p flow.py -l local-agent

# %%
! prefect get flows

# %%
! prefect describe flows --name "update huggingface data"

# %%
! prefect run -n "update huggingface data" --run-name "test run" --log-level DEBUG --watch

# %%
! prefect get flow-runs --flow "update huggingface data"

# %% [markdown]
# # Update
